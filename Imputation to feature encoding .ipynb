# %%
import pandas as pd
import numpy as np
import sys
import warnings
warnings.filterwarnings("ignore")

# %%
# increase the default column
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
df=pd.read_csv("D:\hypo .2.csv")

# %%
df
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     41   f            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 3767  30   F            f                  f                         f    f
# 3768  68   F            f                  f                         f    f
# 3769  74   F            f                  f                         f    f
# 3770  72   M            f                  f                         f    f
# 3771  64   F            f                  f                         f    f
#
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     41   f            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 3767  30   F            f                  f                         f    f
# 3768  68   F            f                  f                         f    f
# 3769  74   F            f                  f                         f    f
# 3770  72   M            f                  f                         f    f
# 3771  64   F            f                  f                         f    f
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3711 entries, 0 to 3771
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        3711 non-null   object
#  1   sex                        3711 non-null   object
#  2   on_thyroxine               3711 non-null   object
#  3   query_on_thyroxine         3711 non-null   object
#  4   on_antithyroid_medication  3711 non-null   object
#  5   sick                       3711 non-null   object
#  6   pregnant                   3711 non-null   object
#  7   thyroid_surgery            3711 non-null   object
#  8   I131_treatment             3711 non-null   object
#  9   query_hypothyroid          3711 non-null   object
#  10  query_hyperthyroid         3711 non-null   object
#  11  lithium                    3711 non-null   object
#  12  goitre                     3711 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# on_thyroxine                 0
# query_on_thyroxine           0
# on_antithyroid_medication    0
# sick                         0
# pregnant                     0
# thyroid_surgery              0
# I131_treatment               0
# query_hypothyroid            0
# query_hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# TSH_measured                 0
# TSH                          0
# T3_measured                  0
# T3                           0
# TT4_measured                 0
# TT4                          0
# T4U_measured                 0
# T4U                          0
# FTI_measured                 0
# FTI                          0
# TBG_measured                 0
# TBG                          0
# referral_source              0
# Class                        0
# ...

# %%
df=df.replace('?',np.nan)

# %%
df.isnull().sum()
# Out:
# age                             1
# sex                           149
# on_thyroxine                    0
# query_on_thyroxine              0
# on_antithyroid_medication       0
# sick                            0
# pregnant                        0
# thyroid_surgery                 0
# I131_treatment                  0
# query_hypothyroid               0
# query_hyperthyroid              0
# lithium                         0
# goitre                          0
# tumor                           0
# hypopituitary                   0
# psych                           0
# TSH_measured                    0
# TSH                           309
# T3_measured                     0
# T3                            709
# TT4_measured                    0
# TT4                           171
# T4U_measured                    0
# T4U                           327
# FTI_measured                    0
# FTI                           325
# TBG_measured                    0
# ...

# %%
# Now we look on imputation 
from sklearn.impute import KNNImputer
imputer=KNNImputer()

# %%
imputer.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14696\1064110353.py in ?()
# ----> 1 imputer.fit_transform(df)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#     874         # non-optimized default implementation; override when a better
#     875         # method is possible for a given clustering algorithm
#     876         if y is None:
# ...

# %%
# class encoding
df['Class'].value_counts()
# Out:
# Class
# 1    3420
# 0     194
# 2      95
# 3       2
# Name: count, dtype: int64

# %%
df['Class'].unique()
# Out:
# array(['negative', 'compensated_hypothyroid', 'primary_hypothyroid',
#        'secondary_hypothyroid'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encode=LabelEncoder()

# %%
df['Class']=label_encode.fit_transform(df['Class'])

# %%
df
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     41   f            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 3767  30   F            f                  f                         f    f
# 3768  68   F            f                  f                         f    f
# 3769  74   F            f                  f                         f    f
# 3770  72   M            f                  f                         f    f
# 3771  64   F            f                  f                         f    f
#
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 1    3420
# 0     194
# 2      95
# 3       2
# Name: count, dtype: int64

# %%
df['Class']=df['Class'].replace({'negative':1,'compensated_hypothyroid':0,'primary_hypothyroid':0,'secondary_hypothyroid':0, })

# %%
df['Class'].value_counts()
# Out:
# Class
# 1    3420
# 0     194
# 2      95
# 3       2
# Name: count, dtype: int64
